# %%
import pandas as pd  # for data wrangling purpose
import numpy as np   # Basic computation library
import seaborn as sns # For Visualization
import matplotlib.pyplot as plt  # ploting package
# %matplotlib inline
import warnings  # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Importing Random Price dataset csv file using pandas
df = pd.read_csv('Random Price Dataset.csv')

# %%
df.head()
# Out:
#          Date  Domestic Market (Contract) Blow Molding, Low  \
# 0  01/01/2000                                            41
# 1  01/02/2000                                            41
# 2  01/03/2000                                            45
# 3  01/04/2000                                            47
# 4  01/05/2000                                            47
#
#    Spot/Export Blow Molding  Spot, Domestic  WTISPLC  MCOILBRENTEU  GASREGM  \
# 0                       NaN             NaN    27.18         25.51    1.289
# 1                       NaN             NaN    29.35         27.78    1.377
# 2                       NaN             NaN    29.89         27.49    1.516
# 3                       NaN             NaN    25.74         22.76    1.465
# 4                       NaN             NaN    28.78         27.74    1.487
#
#     IMPCH   EXPCH  PRUBBUSDM  ...  Russia_import  South_Africa_import  \
# 0  6902.1   863.1  29.207387  ...            NaN                  NaN
# 1  6584.4   972.7  33.391099  ...            NaN                  NaN
# 2  6424.1  1330.5  30.941913  ...            NaN                  NaN
# 3  7070.5  1227.5  31.930148  ...            NaN                  NaN
# 4  7850.2  1526.3  31.201702  ...            NaN                  NaN
#
#    Turkey_import  Brazil_import  France_import  Germeny_import  \
# 0   6,833,222.00   2,649,293.00  35,239,920.00             NaN
# 1   5,647,987.00   2,787,667.00  36,716,752.00             NaN
# 2   6,721,125.00   4,692,701.00  45,144,561.00             NaN
# 3   7,169,182.00   2,565,068.00  32,240,349.00             NaN
# 4  10,466,333.00   4,671,325.00  29,351,633.00             NaN
#
#    United Kingdome_import  China_import  Japan_import  South_korea_import
# 0                     NaN           NaN           NaN                 NaN
# 1                     NaN           NaN           NaN                 NaN
# 2                     NaN           NaN           NaN                 NaN
# 3                     NaN           NaN           NaN                 NaN
# 4                     NaN           NaN           NaN                 NaN
#
# [5 rows x 50 columns]

# %%
df.tail()
# Out:
#            Date  Domestic Market (Contract) Blow Molding, Low  \
# 271  01/08/2022                                            93
# 272  01/09/2022                                            90
# 273  01/10/2022                                            90
# 274  01/11/2022                                            90
# 275  01/12/2022                                            90
#
#      Spot/Export Blow Molding  Spot, Domestic  WTISPLC  MCOILBRENTEU  GASREGM  \
# 271                       NaN             NaN    93.67        100.45    3.975
# 272                       NaN             NaN    84.26         89.76    3.700
# 273                       NaN             NaN    87.55         93.33    3.815
# 274                       NaN             NaN    84.37         91.42    3.685
# 275                       NaN             NaN    76.44         80.92    3.210
#
#            IMPCH        EXPCH  PRUBBUSDM  ...  Russia_import  \
# 271  50348.83658  12906.70000  73.304558  ...            NaN
# 272  49247.89150  11953.51058  66.956499  ...            NaN
# 273  44571.96712  15698.33965  68.535729  ...            NaN
# 274  36876.43705  15576.00600  65.265834  ...            NaN
# 275          NaN          NaN        NaN  ...            NaN
#
#      South_Africa_import  Turkey_import  Brazil_import  France_import  \
# 271        19,310,108.00            NaN            NaN            NaN
# 272        14,410,445.00            NaN            NaN            NaN
# 273        16,783,023.00            NaN            NaN            NaN
# 274        11,079,039.00            NaN            NaN            NaN
# 275                  NaN            NaN            NaN            NaN
#
#      Germeny_import  United Kingdome_import  China_import   Japan_import  \
# 271  144,131,334.00           81,872,550.00           NaN  26,097,012.00
# 272  113,310,929.00           74,477,441.00           NaN  21,277,339.00
# 273  119,307,001.00          109,421,098.00           NaN            NaN
# 274             NaN                     NaN           NaN            NaN
# 275             NaN                     NaN           NaN            NaN
#
#      South_korea_import
# 271                 NaN
# 272                 NaN
# 273                 NaN
# 274                 NaN
# 275                 NaN
#
# [5 rows x 50 columns]

# %%
df1=df.reset_index()['Domestic Market (Contract) Blow Molding, Low']

# %%
df1
# Out:
# 0      41
# 1      41
# 2      45
# 3      47
# 4      47
#        ..
# 271    93
# 272    90
# 273    90
# 274    90
# 275    90
# Name: Domestic Market (Contract) Blow Molding, Low, Length: 276, dtype: int64

# %%
plt.plot(df1)

# %%
### LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
df1
# Out:
# 0      41
# 1      41
# 2      45
# 3      47
# 4      47
#        ..
# 271    93
# 272    90
# 273    90
# 274    90
# 275    90
# Name: Domestic Market (Contract) Blow Molding, Low, Length: 276, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.11842105]
#  [0.11842105]
#  [0.17105263]
#  [0.19736842]
#  [0.19736842]
#  [0.19736842]
#  [0.19736842]
#  [0.18421053]
#  [0.17105263]
#  [0.14473684]
#  [0.13157895]
#  [0.11842105]
#  [0.11842105]
#  [0.18421053]
#  [0.22368421]
#  [0.22368421]
#  [0.18421053]
#  [0.15789474]
#  [0.11842105]
#  [0.07894737]
#  [0.06578947]
#  [0.05263158]
#  [0.03947368]
#  [0.02631579]
#  [0.01315789]
#  [0.        ]
#  [0.03947368]
#  [0.06578947]
#  [0.06578947]
#  [0.10526316]
#  [0.13157895]
#  [0.13157895]
#  [0.13157895]
#  [0.13157895]
#  [0.11842105]
#  [0.10526316]
#  [0.13157895]
#  [0.17105263]
#  [0.25      ]
#  [0.25      ]
#  [0.22368421]
#  [0.19736842]
#  [0.18421053]
#  [0.18421053]
#  [0.22368421]
#  [0.23684211]
#  [0.23684211]
#  [0.23684211]
#  [0.23684211]
#  [0.26315789]
#  [0.27631579]
#  [0.25      ]
#  [0.28947368]
#  [0.23684211]
#  [0.23684211]
#  [0.28947368]
#  [0.28947368]
#  [0.35526316]
#  [0.43421053]
#  [0.43421053]
#  [0.43421053]
#  [0.43421053]
#  [0.43421053]
#  [0.40789474]
#  [0.35526316]
#  [0.30263158]
#  [0.30263158]
#  [0.38157895]
#  [0.51315789]
#  [0.61842105]
#  [0.72368421]
#  [0.67105263]
#  [0.61842105]
#  [0.56578947]
#  [0.51315789]
#  [0.46052632]
#  [0.5       ]
#  [0.53947368]
#  [0.53947368]
#  [0.60526316]
#  [0.57894737]
#  [0.5       ]
#  [0.42105263]
#  [0.38157895]
#  [0.38157895]
#  [0.42105263]
#  [0.46052632]
#  [0.46052632]
#  [0.51315789]
#  [0.51315789]
#  [0.57894737]
#  [0.57894737]
#        [0.64473684],
#        [0.69736842],
#        [0.69736842],
#        [0.69736842],
#        [0.73684211],
#        [0.76315789],
#        [0.84210526],
#        [0.84210526],
#        [0.80263158],
#        [0.75      ],
#        [0.75      ],
#        [0.75      ],
#        [0.68421053],
#        [0.68421053],
#        [0.75      ],
#        [0.75      ],
#        [0.78947368],
#        [0.82894737],
#        [0.82894737],
#        [0.73684211],
#        [0.64473684],
#        [0.64473684],
#        [0.71052632],
#        [0.71052632],
#        [0.71052632],
#        [0.68421053],
#        [0.68421053],
#        [0.75      ],
#        [0.80263158],
#        [0.80263158],
#        [0.80263158],
#        [0.80263158],
#        [0.82894737],
#        [0.82894737],
#        [0.82894737],
#        [0.89473684],
#        [0.89473684],
#        [0.89473684],
#        [0.89473684],
#        [0.89473684],
#        [0.94736842],
#        [0.94736842],
#        [0.94736842],
#        [0.94736842],
#        [0.94736842],
#        [0.94736842],
#        [0.94736842],
#        [0.98684211],
#        [0.98684211],
#        [0.94736842]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 10
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (168, 10)
# (168,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (86, 10)
# (86,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(10,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 50)            10400
#
#  lstm_1 (LSTM)               (None, 10, 50)            20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 8s 749ms/step - loss: 0.2934 - val_loss: 0.2301
# Epoch 2/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1554 - val_loss: 0.0847
# Epoch 3/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0465 - val_loss: 0.0384
# Epoch 4/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0458 - val_loss: 0.0804
# Epoch 5/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0494 - val_loss: 0.0347
# Epoch 6/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0228 - val_loss: 0.0364
# Epoch 7/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0310 - val_loss: 0.0475
# Epoch 8/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0351 - val_loss: 0.0412
# Epoch 9/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0269 - val_loss: 0.0311
# Epoch 10/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0201 - val_loss: 0.0329
# Epoch 11/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0226 - val_loss: 0.0375
# Epoch 12/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0228 - val_loss: 0.0327
# Epoch 13/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0184 - val_loss: 0.0306
# Epoch 14/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0184 - val_loss: 0.0324
# Epoch 15/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0191 - val_loss: 0.0319
# Epoch 16/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0177 - val_loss: 0.0313
# Epoch 17/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0168 - val_loss: 0.0330
# Epoch 18/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0170 - val_loss: 0.0334
# Epoch 19/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0163 - val_loss: 0.0322
# Epoch 20/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0159 - val_loss: 0.0324
# Epoch 21/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0163 - val_loss: 0.0326
# Epoch 22/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0161 - val_loss: 0.0330
# Epoch 23/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0157 - val_loss: 0.0335
# Epoch 24/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0158 - val_loss: 0.0335
# Epoch 25/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0158 - val_loss: 0.0332
# Epoch 26/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0157 - val_loss: 0.0331
# Epoch 27/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0156 - val_loss: 0.0330
# Epoch 28/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0156 - val_loss: 0.0330
# Epoch 29/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0157 - val_loss: 0.0329
# Epoch 30/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0156 - val_loss: 0.0328
# Epoch 31/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0156 - val_loss: 0.0327
# Epoch 32/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0155 - val_loss: 0.0328
# Epoch 33/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0155 - val_loss: 0.0327
# Epoch 34/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0155 - val_loss: 0.0325
# Epoch 35/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0157 - val_loss: 0.0321
# Epoch 36/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0155 - val_loss: 0.0323
# Epoch 37/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0154 - val_loss: 0.0320
# Epoch 38/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0153 - val_loss: 0.0320
# Epoch 39/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0153 - val_loss: 0.0321
# Epoch 40/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0153 - val_loss: 0.0318
# Epoch 41/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0153 - val_loss: 0.0317
# Epoch 42/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0152 - val_loss: 0.0317
# Epoch 43/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0152 - val_loss: 0.0318
# Epoch 44/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0152 - val_loss: 0.0317
# Epoch 45/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0152 - val_loss: 0.0313
# Epoch 46/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0151 - val_loss: 0.0312
# Epoch 47/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0151 - val_loss: 0.0315
# Epoch 48/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0151 - val_loss: 0.0312
# Epoch 49/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0152 - val_loss: 0.0309
# Epoch 50/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0150 - val_loss: 0.0311
# Epoch 51/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0152 - val_loss: 0.0317
# Epoch 52/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0150 - val_loss: 0.0308
# Epoch 53/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0150 - val_loss: 0.0306
# Epoch 54/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0149 - val_loss: 0.0308
# Epoch 55/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0148 - val_loss: 0.0311
# Epoch 56/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0148 - val_loss: 0.0310
# Epoch 57/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0149 - val_loss: 0.0305
# Epoch 58/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0148 - val_loss: 0.0305
# Epoch 59/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0146 - val_loss: 0.0307
# Epoch 60/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0147 - val_loss: 0.0307
# Epoch 61/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0146 - val_loss: 0.0302
# Epoch 62/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0145 - val_loss: 0.0300
# Epoch 63/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0145 - val_loss: 0.0300
# Epoch 64/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0145 - val_loss: 0.0300
# Epoch 65/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0148 - val_loss: 0.0294
# Epoch 66/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0145 - val_loss: 0.0297
# Epoch 67/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0144 - val_loss: 0.0295
# Epoch 68/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0146 - val_loss: 0.0290
# Epoch 69/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0143 - val_loss: 0.0292
# Epoch 70/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0148 - val_loss: 0.0298
# Epoch 71/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0143 - val_loss: 0.0286
# Epoch 72/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0144 - val_loss: 0.0285
# Epoch 73/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0140 - val_loss: 0.0291
# Epoch 74/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0144 - val_loss: 0.0299
# Epoch 75/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0142 - val_loss: 0.0281
# Epoch 76/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0141 - val_loss: 0.0279
# Epoch 77/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0139 - val_loss: 0.0284
# Epoch 78/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0146 - val_loss: 0.0297
# Epoch 79/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0144 - val_loss: 0.0275
# Epoch 80/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0141 - val_loss: 0.0273
# Epoch 81/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0138 - val_loss: 0.0275
# Epoch 82/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0136 - val_loss: 0.0278
# Epoch 83/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0137 - val_loss: 0.0270
# Epoch 84/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0137 - val_loss: 0.0265
# Epoch 85/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0138 - val_loss: 0.0268
# Epoch 86/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0134 - val_loss: 0.0263
# Epoch 87/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0133 - val_loss: 0.0263
# Epoch 88/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0135 - val_loss: 0.0261
# Epoch 89/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0139 - val_loss: 0.0256
# Epoch 90/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0133 - val_loss: 0.0262
# Epoch 91/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0131 - val_loss: 0.0259
# Epoch 92/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0131 - val_loss: 0.0251
# Epoch 93/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0128 - val_loss: 0.0249
# Epoch 94/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0129 - val_loss: 0.0246
# Epoch 95/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0127 - val_loss: 0.0247
# Epoch 96/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0127 - val_loss: 0.0242
# Epoch 97/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0126 - val_loss: 0.0234
# Epoch 98/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0126 - val_loss: 0.0234
# Epoch 99/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0123 - val_loss: 0.0232
# Epoch 100/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0124 - val_loss: 0.0226

# %%
# Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 6/6 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 11ms/step

# %%
#Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
# Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 72.74230908559717

# %%
# Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 78.1058750441276

# %%
## Plotting 
# shift train predictions for plotting
look_back=10
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
